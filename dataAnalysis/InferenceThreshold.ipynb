# %%
#create dictionary: ImagePath, array of FIXMAPS

import pandas as pd
import cv2
import numpy as np
import os
from scipy.ndimage import gaussian_filter
import math
from collections import Counter
import matplotlib.pyplot as plt
import re
import csv
def compute_ppda(distance, h_res, v_res, screen_w, screen_h):
    """
    Compute the number of pixels per degree of visual angle based on the experimental conditions.

    :param distance: int, the distance between the observer and the screen (in mm)
    :param h_res: int, the horizontal resolution of the screen
    :param v_res: int, the vertical resolution of the screen
    :param screen_w: int, the width of the screen (in mm)
    :param screen_h: int, the height of the screen (in mm)
    :return horizontal_ppda: float, the number of pixel per degree of visual angle
    """
    pxl_density_x = h_res / screen_w
    pxl_density_y = v_res / screen_h

    d = 2 * distance * math.tan(np.deg2rad(0.5))
    horizontal_ppda = d * ((pxl_density_x + pxl_density_y) / 2)

    return horizontal_ppda

def checkObserverRemembered(observer, image_path, base_dir):
    csv_file_path = os.path.join(base_dir, ".." ,"hit_status.csv")
    if not os.path.isfile(csv_file_path):
        print("Error: CSV file not found.")
        return False
    df = pd.read_csv(csv_file_path)
    filtered_rows = df[(df['Setup Folder'] == observer) & (df['Image Path'] == image_path) & (df['Hit'] == 1)]
    if not filtered_rows.empty:
        return True
    else:
        return False

distance = 610
h_res = 1920
v_res = 1080
screen_w = 527
screen_h = 296

ppda = compute_ppda(distance, h_res, v_res, screen_w, screen_h)
print("ppda", ppda)

def bin_fixations(fixation_map, grid_size=(30, 30)):
    height, width = fixation_map.shape
    binned_map = np.zeros(grid_size)

    bin_height = height // grid_size[0]
    bin_width = width // grid_size[1]

    for i in range(grid_size[0]):
        for j in range(grid_size[1]):
            bin_area = fixation_map[i*bin_height:(i+1)*bin_height, j*bin_width:(j+1)*bin_width]
            binned_map[i, j] = np.sum(bin_area)
            #ili avg?

    return binned_map

def normalize_map(binned_map):
    return binned_map / np.sum(binned_map)
    #return binned_map

def smooth_map(binned_map, sigma=1):
    return gaussian_filter(binned_map, sigma=sigma)

def process_fixation_map(fixation_map):
    binned_map = bin_fixations(fixation_map)
    normalized_map = normalize_map(binned_map)
    smoothed_map = smooth_map(normalized_map)
    return smoothed_map

def get_current_fixation_map(image_path, coordinates):
    image = cv2.imread(image_path)
    if image is None:
        print(f"Image at {image_path} not found.")
        return

    coordinates = coordinates[0:120]
  
    fixation_map = np.zeros((1080, 1920), dtype=np.float32)

    # Convert coordinates to pixel coordinates and update the saliency map
    for x_norm, y_norm in coordinates:
        # Scale normalized coordinates to pixel coordinates for the 1920x1080 screen
        x = int(((x_norm + 1) / 2 ) * 1920)  # Scaling from (-1, 1) to (0, 1920) range
        y = int((y_norm + 0.5) * 1080) # Scaling from (-0.5, 0.5) to (0, 1080) range
        # Update the saliency map if coordinates are within the screen
        if 0 <= x < 1920 and 0 <= y < 1080:
            fixation_map[y, x] += 1 
    #sigma = ppda / np.sqrt(2)
    #fixation_map = gaussian_filter(fixation_map, sigma = sigma)
    fixation_map = cv2.GaussianBlur(fixation_map, (43, 43), 0)
    # Crop the saliency map to the 700x700 region
    fixation_map = fixation_map[190:890, 610:1310]
    # flip the Y coordinates
    fixation_map = np.flipud(fixation_map)
    return fixation_map

def normalize_fixation_map(fixation_map):
    min_val = np.min(fixation_map)
    max_val = np.max(fixation_map)
    normalized_fixation_map = (fixation_map - min_val) / (max_val - min_val) * 255
    return normalized_fixation_map

# 90experiments folder
base_dir = os.path.abspath(os.path.join(os.getcwd(),"..", "..", "..", "90experiments"))

successful_fixation_maps = {}  # Dictionary to store fixation maps for each imagePath
unsuccessful_fixation_maps = {}

for folder in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, folder)
    if not os.path.isdir(folder_path):
        continue
    match = re.search(r'\d{1,2}$', folder)
    if match:
        observer = int(match.group())
    #if(observer != 5):
    #    continue
    if(observer == 1 or observer == 2 or observer == 49 or observer == 50 or observer == 5):
        continue

    #if(observer not in [70,71,73,74,76,77,79,80,82,83,85,87,88,89,86,90,18,57,6,45,48,60,63,69,3,9,12,21,15,27,30,33,36,42,24,66,51,54,72,75]):
    #    continue
        
    csv_file_path = os.path.join(folder_path, "eye_tracker_data.csv")
    if not os.path.isfile(csv_file_path):
        continue
    data = pd.read_csv(csv_file_path)

    filtered_data = data[data['ImagePath'].str.startswith('targetImages')]
    
    uniqueImagePaths = []
    delete_rows = []

    #get only the eye-tracking data from the first viewing
    index = 0
    
    row = filtered_data.iloc[index]
    while len(uniqueImagePaths) < 10:
        row = filtered_data.iloc[index]
        if(row['ImagePath'] not in uniqueImagePaths):
            uniqueImagePaths.append(row['ImagePath'])
            lastImagePath = row['ImagePath']
            index +=1
        elif(row['ImagePath'] in uniqueImagePaths):
            index += 1    
    row = filtered_data.iloc[index]

    while(row['ImagePath'] == lastImagePath):
        index +=1
        row = filtered_data.iloc[index]

    filtered_data.reset_index(drop=True, inplace=True)
    filtered_data = filtered_data.iloc[:index].copy()
    
    grouped = filtered_data.groupby('ImagePath')

    # Generate and save fixation maps for each image in the current folder
    for image_path, group in grouped:
        # Construct full image path by going one directory back from base_dir
        full_image_path = os.path.abspath(os.path.join(base_dir, "..", image_path))
        full_image_path = full_image_path.replace('\\', '/')

        # Extract coordinates
        coordinates = group[['PosX', 'PosY']].values

        current_fixation_map = get_current_fixation_map (full_image_path, coordinates)
        if(np.all(current_fixation_map == 0)):
            continue

        current_fixation_map_20x20 = process_fixation_map(current_fixation_map)
        current_fixation_map_20x20 = normalize_fixation_map(current_fixation_map_20x20)
        
        if(not checkObserverRemembered(observer, image_path, base_dir)):
            #add to unsuccessful ones
            if image_path not in unsuccessful_fixation_maps:
                unsuccessful_fixation_maps[image_path] = [current_fixation_map_20x20]
            else:
                unsuccessful_fixation_maps[image_path].append(current_fixation_map_20x20)
            continue
        #add to successful ones
        if image_path not in successful_fixation_maps:
            successful_fixation_maps[image_path] = [current_fixation_map_20x20]
        else:
            successful_fixation_maps[image_path].append(current_fixation_map_20x20)
    

print("finished")
#print((fixation_maps['targetImages\\sun_aesdwymqhhiewhyo.jpg']))
# Out:
# ppda 38.81768885920885
# finished

# %%
# Flatten the fixation maps and standardize them

successful_labels = []

for image_path, maps in successful_fixation_maps.items():
    for fixation_map in maps:
        fixation_map = (fixation_map.flatten())
    maps = np.array(maps)
    maps = maps.reshape(-1,30,30,1)
    
for image_path, maps in unsuccessful_fixation_maps.items():
    for fixation_map in maps:
        fixation_map = (fixation_map.flatten())
    maps = np.array(maps)
    maps = maps.reshape(-1,30,30,1)

#print((successful_fixation_maps['targetImages\\sun_aesdwymqhhiewhyo.jpg']))
#print(successful_fixation_maps['targetImages\\sun_aesdwymqhhiewhyo.jpg'][0].shape)
#print(successful_fixation_maps['targetImages\\sun_aesdwymqhhiewhyo.jpg'][0].reshape(-1,20,20,1))
#print(successful_fixation_maps['targetImages\\sun_aesdwymqhhiewhyo.jpg'][0].shape)

# %%
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

def get_prediction(input_data, loaded_model, truth):
    input_data = input_data.reshape(1, 30, 30, 1)

    # Perform prediction
    predictions = loaded_model.predict(input_data, verbose=0)
    predicted_class = np.argmax(predictions, axis=1)
    if(predicted_class[0] == truth):
        #if the models' first prediction IS the correct one
        confidence_level = predictions[0][truth]
    else:
        #if the model's first prediction IS NOT the correct one, we penalize that
        confidence_level = 0
    return confidence_level

def find_best_threshold(successful_confidence_levels, unsuccessful_confidence_levels):
    all_confidences = np.concatenate([successful_confidence_levels, unsuccessful_confidence_levels])
    labels = np.concatenate([np.ones(len(successful_confidence_levels)), np.zeros(len(unsuccessful_confidence_levels))])
    
    best_threshold = 0
    best_accuracy = 0
    
    for threshold in np.linspace(0, 1, 1001):  # Test thresholds between 0 and 1 with a step of 0.01
        predictions = all_confidences >= threshold
        accuracy = np.mean(predictions == labels)
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_threshold = threshold
            
    return best_threshold, best_accuracy

# Set the path to the saved model and target images folder
model_path = os.path.join('..', '..', 'AllModels', 'best MLP model CEPAJ', 'best_model.keras')
target_images_folder = os.path.join('..', '..', '..', 'targetImages')

# Check if the file exists
if os.path.exists(model_path):
    # Load the model
    loaded_model = tf.keras.models.load_model(model_path)
else:
    print(f"Model file not found: {model_path}")
    exit()

# Create a grid for subplots (6x5 for 30 images)
fig, axes = plt.subplots(6, 5, figsize=(20, 24))
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easy iteration

average_threshold = 0
average_accuracy = 0
image_number = 0

stored_bad_maps = [] # CL > 0.9 successful ones
stored_good_maps = [] # CL > 0.8 unsuccessful

for image_name in os.listdir(target_images_folder):
    current_image = 'targetImages\\'+image_name
    # Successful fixmaps 
    successful_confidence_levels = []
    average_successful_fixation_confidence_level = 0
    cnt1 = 0
    
    current_successful_maps = successful_fixation_maps[current_image]
    for map in current_successful_maps:
        confidence_level = get_prediction(map, loaded_model, image_number)
        if(confidence_level > 0.9 and image_name == "sun_apytdxunawwxcvdw.jpg"):
            stored_good_maps.append(map)
        successful_confidence_levels.append(confidence_level)
        cnt1 += 1 
        average_successful_fixation_confidence_level += confidence_level
        
    average_successful_fixation_confidence_level = average_successful_fixation_confidence_level / cnt1

    # Unsuccessful fixmaps
    unsuccessful_confidence_levels = []
    average_unsuccessful_fixation_confidence_level = 0
    cnt2 = 0

    current_unsuccessful_maps = unsuccessful_fixation_maps[current_image]
    for map in current_unsuccessful_maps:
        confidence_level = get_prediction(map, loaded_model, image_number)
        if(confidence_level > 0.8 and image_name == "sun_apytdxunawwxcvdw.jpg"):
            stored_bad_maps.append(map)
        unsuccessful_confidence_levels.append(confidence_level)
        cnt2 += 1 
        average_unsuccessful_fixation_confidence_level += confidence_level
        
    average_unsuccessful_fixation_confidence_level = average_unsuccessful_fixation_confidence_level / cnt2
    
    # Find the best threshold
    best_threshold, best_accuracy = find_best_threshold(successful_confidence_levels, unsuccessful_confidence_levels)
    print(f"Best threshold for {image_name}: {best_threshold:.4f} with accuracy: {best_accuracy:.4f}")
    
    # Plotting for the current image
    ax = axes[image_number]
    ax.scatter(range(len(successful_confidence_levels)), successful_confidence_levels, color='blue', label='Successful')
    ax.scatter(range(len(unsuccessful_confidence_levels)), unsuccessful_confidence_levels, color='red', label='Unsuccessful')
    
    ax.axhline(y=best_threshold, color='green', linestyle='--', label=f'Threshold: {best_threshold:.2f}')
    
    ax.set_xlabel('Data Point Index')
    ax.set_ylabel('Confidence Level')
    ax.set_title(f'Image: {image_name}')
    ax.legend()
    
    image_number += 1
    average_threshold += best_threshold
    average_accuracy += best_accuracy

# Save the figure with all plots
plt.tight_layout()
plt.savefig('all_image_confidences.png')
plt.show()

print(f"Average Accuracy: {average_accuracy / 30:.4f}")
# Out:
# Best threshold for sun_aesdwymqhhiewhyo.jpg: 0.0000 with accuracy: 0.9286
# Best threshold for sun_aewtvpwulyxhqvuv.jpg: 0.0000 with accuracy: 0.8214
# Best threshold for sun_agenkchqfjxvsppn.jpg: 0.0010 with accuracy: 0.8929
# Best threshold for sun_agoqtmhicqrakxqs.jpg: 0.0010 with accuracy: 0.9259
# Best threshold for sun_ahbwwdffoiigyxqx.jpg: 0.0000 with accuracy: 0.8519
# Best threshold for sun_ailjxpgyepocjdos.jpg: 0.0010 with accuracy: 0.8889
# Best threshold for sun_aiyjrnbytpirechl.jpg: 0.4500 with accuracy: 0.7931
# Best threshold for sun_amkeeuvicewppjqo.jpg: 0.0010 with accuracy: 1.0000
# Best threshold for sun_amssqaxrfmufhwxv.jpg: 0.0010 with accuracy: 0.8077
# Best threshold for sun_aplqnvinpntdexdw.jpg: 0.0010 with accuracy: 0.8148
# Best threshold for sun_apytdxunawwxcvdw.jpg: 0.9850 with accuracy: 0.8519
# Best threshold for sun_arsolpsoaipmhdio.jpg: 0.4530 with accuracy: 0.8929
# Best threshold for sun_ayuqdxlbdhbbgypd.jpg: 0.0000 with accuracy: 0.7778
# Best threshold for sun_aywhxcvpafxkujrj.jpg: 0.5730 with accuracy: 0.9643
# Best threshold for sun_bacfwopdcsewxkne.jpg: 0.0010 with accuracy: 0.9643
# Best threshold for sun_bgshkoltnrmilxns.jpg: 0.0010 with accuracy: 0.8621
# Best threshold for sun_bisnnysqxgpavrkh.jpg: 0.0000 with accuracy: 0.9231
# Best threshold for sun_bkxzmjorpemztasj.jpg: 0.8110 with accuracy: 1.0000
# Best threshold for sun_bpkiszwjhbnsrmtr.jpg: 0.0010 with accuracy: 0.8889
# Best threshold for sun_btjevcvrxjpeyoxz.jpg: 0.5700 with accuracy: 0.8621
# Best threshold for sun_bukzvwbkvedjexbe.jpg: 0.4650 with accuracy: 0.9643
# Best threshold for sun_burokageiugamrul.jpg: 0.0010 with accuracy: 0.8889
# Best threshold for sun_buubpayscjcxyypt.jpg: 0.7470 with accuracy: 0.8966
# Best threshold for sun_bwidvgzwofvfteaj.jpg: 0.0010 with accuracy: 0.9259
# Best threshold for sun_bxxtkmyydusifqkv.jpg: 0.3750 with accuracy: 0.9231
# Best threshold for sun_byuhjpweygtwpwbj.jpg: 0.5940 with accuracy: 0.9286
# Best threshold for sun_byziwbrwhhpxaydu.jpg: 0.0010 with accuracy: 0.8929
# Best threshold for sun_bzfcixnmhtzpmwij.jpg: 0.0000 with accuracy: 0.9231
# Best threshold for sun_bzjdnotizomfsdad.jpg: 0.9550 with accuracy: 0.8929
# Best threshold for sun_cesisdcqpsijbubk.jpg: 0.0010 with accuracy: 0.8571
# Average Accuracy: 0.8935

# %%
import matplotlib.pyplot as plt
import math

fixation_maps = stored_bad_maps

num_maps = len(fixation_maps)
grid_size = (int(math.ceil(num_maps / 5)), 5)  # Adjust the number of columns (5 here) as needed

plt.figure(figsize=(15, grid_size[0] * 3))

for i, fixation_map in enumerate(fixation_maps):
    plt.subplot(grid_size[0], grid_size[1], i + 1)
    plt.imshow(fixation_map, cmap='hot', interpolation='nearest')
    plt.title(f'Fixation Map {i + 1}')
    plt.axis('off')

plt.suptitle(f'Bad Fixation Maps for {key}')
plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust the space for suptitle
plt.show()

# %%
key = 'targetImages\sun_apytdxunawwxcvdw'

import matplotlib.pyplot as plt
import math

# Function to merge all 20x20 fixation maps into one 20x20 image
def merge_fixation_maps_into_single_image(fixation_maps):
    if not fixation_maps:
        return None
    
    map_size = fixation_maps[0].shape[0]  # Assuming all maps are the same size
    merged_image = np.zeros((map_size, map_size))
    
    for map in fixation_maps:
        merged_image += map
    
    # Normalize the merged image
    if np.max(merged_image) > 0:
        merged_image = merged_image / np.max(merged_image) * 255
    
    return merged_image

fixation_maps = stored_good_maps
        
# Merge fixation maps into a single 20x20 image
merged_image = merge_fixation_maps_into_single_image(fixation_maps)

if merged_image is not None:
    plt.figure(figsize=(6, 6))
    plt.imshow(merged_image, cmap='hot', interpolation='nearest')
    plt.title(f'Merged Best Successful Fixation Maps for {key}')
    plt.axis('off')
    plt.show()

# %%
import matplotlib.pyplot as plt
import math

# Function to merge all 20x20 fixation maps into one 20x20 image
def merge_fixation_maps_into_single_image(fixation_maps):
    if not fixation_maps:
        return None
    
    map_size = fixation_maps[0].shape[0]  # Assuming all maps are the same size
    merged_image = np.zeros((map_size, map_size))
    
    for map in fixation_maps:
        merged_image += map
    
    # Normalize the merged image
    if np.max(merged_image) > 0:
        merged_image = merged_image / np.max(merged_image) * 255
    
    return merged_image

fixation_maps = stored_bad_maps
        
# Merge fixation maps into a single 20x20 image
merged_image = merge_fixation_maps_into_single_image(fixation_maps)

if merged_image is not None:
    plt.figure(figsize=(6, 6))
    plt.imshow(merged_image, cmap='hot', interpolation='nearest')
    plt.title(f'Merged Worst (<20% CL) Unsuccessful Fixation Maps for {key}')
    plt.axis('off')
    plt.show()
